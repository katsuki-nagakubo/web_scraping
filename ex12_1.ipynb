# %%
# linkを取ってくる

import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

# ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urllib.request.urlopen(url, context = ctx).read()
soup = BeautifulSoup(html, 'html.parser')

# Retrive all of the anchor tags
tags = soup('a')
for tag in tags:
    print (tag.get("href", None))
# Out:
# Enter - https://www.soccer-king.jp/news/world?cx_top=newmore
# /
# https://www.soccer-king.jp/%e6%97%a5%e6%9c%ac%e4%bb%a3%e8%a1%a8
# https://www.soccer-king.jp/news/japan
# https://www.soccer-king.jp/news/japan/jl
# https://www.soccer-king.jp/news/japan/nadeshiko
# https://www.soccer-king.jp/news/japan/ync
# https://www.soccer-king.jp/news/japan/highschool
# https://www.soccer-king.jp/stats/japan/j1/match
# https://www.soccer-king.jp/stats/japan/j1/rank/first
# https://www.soccer-king.jp/stats/japan/j1/goal
# https://www.soccer-king.jp/league/j1
# https://www.soccer-king.jp/news/world
# https://www.soccer-king.jp/news/tag/%E6%B5%B7%E5%A4%96%E6%97%A5%E6%9C%AC%E4%BA%BA%E9%81%B8%E6%89%8B
# https://www.soccer-king.jp/news/world/eng
# https://www.soccer-king.jp/news/world/esp
# https://www.soccer-king.jp/news/world/ita
# https://www.soccer-king.jp/news/world/ger
# https://www.soccer-king.jp/news/world/cl
# https://www.soccer-king.jp/worldcup
# ...

# %%
# pのclassが"tit"のものを取ってくる
# 文章内に”メッシ"を含むものを取ってくる

    
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

# ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urllib.request.urlopen(url, context = ctx).read()
soup = BeautifulSoup(html, 'html.parser')

# Retrive all of the anchor tags
# class p の tit を取ってくる
tags = soup.find_all("p", class_= "tit")
for tag in tags:
    tag = tag.text
    if "メッシ" in tag:
        print(tag)
# Out:
# Enter - https://www.soccer-king.jp/news/world?cx_top=newmore
# 「メッシやロナウドを継げる」…エメリ氏、ネイマールと過ごしたシーズンを振り返る
# マルセロがC・ロナウドとメッシを比較…レアル残留希望も公言「去りたくない」
# マルセロがC・ロナウドとメッシを比較…レアル残留希望も公言「去りたくない」
# モウリーニョ監督の元腹心、メッシのインテル移籍の可能性に言及…鍵を握るのは“あのレジェンド”
# GKはケイン、ボランチはフィルミーノとメッシ…FWだけで構成するベスト11がおもしろい！
# 「ケガさえなければ」…C・ロナウド＆メッシより上？　モウリーニョ監督が絶賛する人物とは

# %%
# pのclassが"tit"のものを取ってくる
# 文章内に”メッシ"を含むものを取ってくる

    
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

# ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urllib.request.urlopen(url, context = ctx).read()
soup = BeautifulSoup(html, 'html.parser')

# Retrive all of the anchor tags
# class p の tit を取ってくる
tags = soup.find_all("span", class_="m-miM09_titleL")
for tag in tags:
    if "FRB" in tag.text:
        print (tag.text)
# Out:
# Enter - https://www.nikkei.com/economy/economic/
# FRB、企業融資の対象拡大　従業員1.5万人まで可能
